# %%
import pandas as pd
df=pd.read_csv('Viratkohli100\k.csv')
df
# Out:
#     Number Format  Inning Position  Score  Balls  Strike Rate       Against  \
# 0        1    ODI       2        4    107    114    93.859649     Sri Lanka
# 1        2    ODI       2        3    102     95   107.368421    Bangladesh
# 2        3    ODI       2        3    118    121    97.520661     Australia
# 3        4    ODI       1        3    105    104   100.961539   New Zealand
# 4        5    ODI       1        4    100     83   120.481928    Bangladesh
# ..     ...    ...     ...      ...    ...    ...          ...           ...
# 73      74   Test       1        4    254    336    75.595238  South Africa
# 74      75   Test       2        4    136    194    70.103093    Bangladesh
# 75      76   T20i       1     Open    122     61   200.000000   Afghanistan
# 76      77    ODI       1        3    113     91   124.175824    Bangladesh
# 77      78    ODI       1        3    113     87   129.885057     Sri Lanka
#
# ...

# %%
import pandas as pd
df=pd.read_csv('Viratkohli100\k.csv')
df.loc[1]
# Out:
# Number                   2
# Format                 ODI
# Inning                   2
# Position                 3
# Score                  102
# Balls                   95
# Strike Rate     107.368421
# Against         Bangladesh
# Venue               Mirpur
# Host Nation     Bangladesh
# Series          Tri-Series
# Year                  2010
# Team Total             249
# Wickets lost             4
# Not Out                Yes
# MOTM                   Yes
# Win                    Yes
# Captain                 No
# Name: 1, dtype: object

# %%
import pandas as pd
df=pd.read_csv('Viratkohli100\k.csv')
len(df)
# Out:
# 78

# %%
import pandas as pd
df=pd.read_csv('Viratkohli100\k.csv')
df.head(4)
# Out:
#    Number Format  Inning Position  Score  Balls  Strike Rate      Against  \
# 0       1    ODI       2        4    107    114    93.859649    Sri Lanka
# 1       2    ODI       2        3    102     95   107.368421   Bangladesh
# 2       3    ODI       2        3    118    121    97.520661    Australia
# 3       4    ODI       1        3    105    104   100.961539  New Zealand
#
#       Venue Host Nation      Series  Year  Team Total  Wickets lost Not Out  \
# 0   Kolkata       India   Bilateral  2009         316             3      No
# 1    Mirpur  Bangladesh  Tri-Series  2010         249             4     Yes
# 2     Vizag       India   Bilateral  2010         292             5      No
# 3  Guwahati       India   Bilateral  2010         276            10      No
#
#   MOTM  Win Captain
# 0   No  Yes      No
# 1  Yes  Yes      No
# 2  Yes  Yes      No
# 3  Yes  Yes      No

# %%
import pandas as pd
df=pd.read_csv('Viratkohli100\k.csv')
df.tail(5)
# Out:
#     Number Format  Inning Position  Score  Balls  Strike Rate       Against  \
# 73      74   Test       1        4    254    336    75.595238  South Africa
# 74      75   Test       2        4    136    194    70.103093    Bangladesh
# 75      76   T20i       1     Open    122     61   200.000000   Afghanistan
# 76      77    ODI       1        3    113     91   124.175824    Bangladesh
# 77      78    ODI       1        3    113     87   129.885057     Sri Lanka
#
#          Venue Host Nation     Series  Year  Team Total  Wickets lost Not Out  \
# 73        Pune       India  Bilateral  2019         601             5     Yes
# 74     Kolkata       India  Bilateral  2019         347             9      No
# 75       Dubai         UAE   Asia Cup  2022         212             2     Yes
# 76  Chattogram  Bangladesh  Bilateral  2022         409             8      No
# 77    Guwahati       India  Bilateral  2023         373             7      No
#
#    MOTM  Win Captain
# ...

# %%
import pandas as pd
df=pd.read_csv('Viratkohli100\k.csv')
df.Against
# Out:
# 0        Sri Lanka
# 1       Bangladesh
# 2        Australia
# 3      New Zealand
# 4       Bangladesh
#           ...
# 73    South Africa
# 74      Bangladesh
# 75     Afghanistan
# 76      Bangladesh
# 77       Sri Lanka
# Name: Against, Length: 78, dtype: object

# %%
import pandas as pd
df=pd.read_csv('Viratkohli100\k.csv')
df.Against.head(6)
# Out:
# 0      Sri Lanka
# 1     Bangladesh
# 2      Australia
# 3    New Zealand
# 4     Bangladesh
# 5        England
# Name: Against, dtype: object

# %%
import pandas as pd
df=pd.read_csv('Viratkohli100\k.csv')
df.query('Score > 80').head(2)
# Out:
#    Number Format  Inning Position  Score  Balls  Strike Rate     Against  \
# 0       1    ODI       2        4    107    114    93.859649   Sri Lanka
# 1       2    ODI       2        3    102     95   107.368421  Bangladesh
#
#      Venue Host Nation      Series  Year  Team Total  Wickets lost Not Out  \
# 0  Kolkata       India   Bilateral  2009         316             3      No
# 1   Mirpur  Bangladesh  Tri-Series  2010         249             4     Yes
#
#   MOTM  Win Captain
# 0   No  Yes      No
# 1  Yes  Yes      No

# %%
import pandas as pd
df=pd.read_csv('Viratkohli100\k.csv')
df.query('Score > 80').head(4)
# Out:
#    Number Format  Inning Position  Score  Balls  Strike Rate      Against  \
# 0       1    ODI       2        4    107    114    93.859649    Sri Lanka
# 1       2    ODI       2        3    102     95   107.368421   Bangladesh
# 2       3    ODI       2        3    118    121    97.520661    Australia
# 3       4    ODI       1        3    105    104   100.961539  New Zealand
#
#       Venue Host Nation      Series  Year  Team Total  Wickets lost Not Out  \
# 0   Kolkata       India   Bilateral  2009         316             3      No
# 1    Mirpur  Bangladesh  Tri-Series  2010         249             4     Yes
# 2     Vizag       India   Bilateral  2010         292             5      No
# 3  Guwahati       India   Bilateral  2010         276            10      No
#
#   MOTM  Win Captain
# 0   No  Yes      No
# 1  Yes  Yes      No
# 2  Yes  Yes      No
# 3  Yes  Yes      No

# %%
import pandas as pd
df=pd.read_csv('Viratkohli100\k.csv')
df.query('Score > 80').tail(5)
# Out:
#     Number Format  Inning Position  Score  Balls  Strike Rate       Against  \
# 73      74   Test       1        4    254    336    75.595238  South Africa
# 74      75   Test       2        4    136    194    70.103093    Bangladesh
# 75      76   T20i       1     Open    122     61   200.000000   Afghanistan
# 76      77    ODI       1        3    113     91   124.175824    Bangladesh
# 77      78    ODI       1        3    113     87   129.885057     Sri Lanka
#
#          Venue Host Nation     Series  Year  Team Total  Wickets lost Not Out  \
# 73        Pune       India  Bilateral  2019         601             5     Yes
# 74     Kolkata       India  Bilateral  2019         347             9      No
# 75       Dubai         UAE   Asia Cup  2022         212             2     Yes
# 76  Chattogram  Bangladesh  Bilateral  2022         409             8      No
# 77    Guwahati       India  Bilateral  2023         373             7      No
#
#    MOTM  Win Captain
# ...
